# %%
import numpy as np
from scipy import ndimage 
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
#         ...,
#         [120, 156,  95],
#         [119, 155,  93],
#         [118, 154,  92]]], dtype=uint8)

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()

# %%
#dar la vuelta al array
mapache180  = mapache[::-1]
plt.imshow(mapache180)
plt.show()

# %%
mp1,mp2 = np.hsplit(mapache,2)
plt.imshow(mp1)
plt.show()

# %%
plt.imshow(mp2)
plt.show()

# %%
mapachesum = mapache + 1
plt.imshow(mapachesum)
plt.show()

# %%
#Desenfoque de imagen
#Es necesario aplicar un filtro gaussiano
mapachedesenfocado = ndimage.gaussian_filter(mapache, sigma=5)
plt.imshow(mapachedesenfocado)
plt.show()

# %%
#
mapacheumbral = mapache > 128
alv = list( filter(lambda numero: numero > 128, mapache) )
alv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-47e9e55ced3c> in <module>
#       1 #
#       2 mapacheumbral = mapache > 128
# ----> 3 alv = list( filter(lambda numero: numero > 128, mapache.all()) )
#       4 alv
#
# TypeError: 'numpy.bool_' object is not iterable

# %%
#Imagen rotada
mapache45 = ndimage.rotate(mapache, 45)
plt.imshow(mapache45)
plt.show()

# %%
#Mapache rompecabezas 16
n = 4
puzzle = [[0 for x in range(n)] for y in range(n)] 
puzzle_hash = [[0 for x in range(n)] for y in range(n)] 
jigsawh = np.hsplit(mapache,n)
for i in range(n):
    jigsawv = np.vsplit(jigsawh[i],n)
    for j in range(n):
        puzzle[i][j] = jigsawv[j] 
        puzzle_hash[i][j] = str(hash((puzzle[i][j]).tostring()))

plt.imshow(puzzle[3][3])
plt.show()
print(puzzle_hash[0][2])

#from numpy import array
#puzzle_hash = array(puzzle_hash)
# Out:
# -2728395011957070266

# %%
import random
#dimensions = (n,n)
#matriz = np.zeros(dimensions) 

#shuffle_puzzle = np.random.shuffle(puzzle_hash)
#shuffle(foo)
#map(shuffle, foo)
#col_idx = np.random.permutation(puzzle.shape[1])
#shuffled_a = a[:,col_idx]
#type(shuffle_puzzle)
#type(shuffle_puzzle)
#plt.imshow(shuffle_puzzle[3][3])
#plt.show()
import random
#print(random.shuffle((puzzle_hash[0])))
print(random.shuffle(puzzle_hash[0]))
#shuffled_matrix =np.random.shuffle(puzzle_hash[0]))
# Out:
# None
